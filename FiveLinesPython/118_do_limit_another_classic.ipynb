# %%
# how to do the limit to this one

# %%
from sympy import Symbol, Limit, sin, pprint

# %%
x = Symbol('x')
myLimit = Limit(sin(x)/x, x, 0)

# %%
pprint(myLimit)
# Out:
#      ⎛sin(x)⎞
#  lim ⎜──────⎟
# x─→0⁺⎝  x   ⎠

# %%
myLimit.doit()
# Out:
# 1
