# %%
# how to create a pandas series

# %%
import pandas as pd

# %%
grades = pd.Series([4, 3, 2, 1], 
                   index = ['A', 'B', 'C', 'D'])

# %%
print(grades)
# Out:
# A    4
# B    3
# C    2
# D    1
# dtype: int64

# %%
type(grades)
# Out:
# pandas.core.series.Series

# %%
grades['A']
# Out:
# 4
