# %%
# how to append a list from its head or its tail

# %%
myList = [2, 3, 4]

# %%
# how to add 1 to the beginning, and 5 to the end ?

# %%
myList[:0] = [1]

# %%
print(myList)
# Out:
# [1, 2, 3, 4]

# %%
myList[len(myList):] = [5]

# %%
print(myList)
# Out:
# [1, 2, 3, 4, 5]
