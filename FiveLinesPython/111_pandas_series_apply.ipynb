# %%
# how to create a pandas series

# %%
import pandas as pd

# %%
mySeries = pd.Series([4, 3, 2, 1], 
                   index = [1, 2, 3, 4])

# %%
print(mySeries)
# Out:
# 1    4
# 2    3
# 3    2
# 4    1
# dtype: int64

# %%
func = lambda x: x**2

# %%
mySeries.apply(func)
# Out:
# 1    16
# 2     9
# 3     4
# 4     1
# dtype: int64
