# %%
# how to do derivatives in python

# %%
from sympy import Symbol, Derivative

# %%
x = Symbol('x')
myEqu = 2*x**2 + 4*x + 6

# %%
Derivative(myEqu, x)
# Out:
# Derivative(2*x**2 + 4*x + 6, x)

# %%
der = Derivative(myEqu, x)

# %%
der.doit()
# Out:
# 4*x + 4
