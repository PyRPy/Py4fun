# %%
# how to do limit in python

# %%
from sympy import Symbol, Limit, S, pprint

# %%
x = Symbol('x')

# %%
myExp = Limit((1 + 1/x)**x, x, S.Infinity)

# %%
pprint(myExp)
# Out:
#            x
#     ⎛    1⎞
# lim ⎜1 + ─⎟
# x─→∞⎝    x⎠

# %%
myExp.doit()
# Out:
# E
