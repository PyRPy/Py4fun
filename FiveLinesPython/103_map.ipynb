# %%
# how to use map

# %%
def square(x):
  return x**2

# %%
# square every element in a list
myList = [1, 2, 3, 4, 5]

# %%
mySquareList = map(square, myList)

# %%
mySquareList.__next__()
# Out:
# 25
