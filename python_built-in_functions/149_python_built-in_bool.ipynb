# %%
# python built-in functions: bool

# %%
nums = [1, 2, 3, 4, 5]

# %%
print(bool(nums))
# Out:
# True

# %%
nums = []
print(bool(nums))
# Out:
# False

# %%
nums = [0]
print(bool(nums))
# Out:
# True

# %%
num = 1 # change between 1 and 0
print(bool(num))
# Out:
# True
