# %%
# python built-in functions: bytearray

# %%
nums = [1, 2, 3, 4, 5]

# %%
print(bytearray(nums))
# Out:
# bytearray(b'\x01\x02\x03\x04\x05')

# %%
myChars = bytearray(b'xyz')

# %%
for val in myChars:
  print(val)
# Out:
# 120
# 121
# 122

# %%
ord('x') # check it in another way
# Out:
# 120
