# %%
# python built-in functions:dict()

# %%
# define an empty dictionary
students = dict()

# %%
# or use {}
students2 = {}

# %%
print(type(students))
# Out:
# <class 'dict'>

# %%
print(type(students2))
# Out:
# <class 'dict'>

# %%
students = dict({1:'Jack', 2:'Matt', 3:'Sara'})
print(students)
# Out:
# {1: 'Jack', 2: 'Matt', 3: 'Sara'}

# %%
students3 = dict([(1,'Jack'), (2,'Matt'), (3,'Sara')])
print(students3)
# Out:
# {1: 'Jack', 2: 'Matt', 3: 'Sara'}

# %%
# so flexible
