# %%
# python built-in functions: eval()

# %%
# write a string of code
myCalcs = '2 + 3'

# %%
# you can run it inside eval()
print(eval(myCalcs))
# Out:
# 5

# %%
# more operations or calculations
print(eval('2**10'))
# Out:
# 1024

# %%
# powerful! too powerful, be careful!
