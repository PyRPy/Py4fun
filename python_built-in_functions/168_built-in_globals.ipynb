# %%
# python built-in functions: globals

# %%
# global variable - to display them

# %%
fruit = 'orange'

# %%
def favorate_fruit():
    string_inside = 'i like '
    print(string_inside + fruit)

# %%
favorate_fruit()
# Out:
# i like orange

# %%
# it contains a dictionary for pairs of variables

# %%
print(globals()['fruit'])
# Out:
# orange
