# %%
# python built-in functions:complex()

# %%
# complex numbers

x = complex(4, 5)
y = complex(1, 1)

# %%
print(x)
# Out:
# (4+5j)

# %%
print(y)
# Out:
# (1+1j)

# %%
# show properties

print(x.imag)
print(x.conjugate())
# Out:
# 5.0
# (4-5j)

# %%
# simple addition

z = x + y
print(z)
# Out:
# (5+6j)
