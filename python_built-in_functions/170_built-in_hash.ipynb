# %%
# python built-in functions: hash

# %%
myTuple = (1, 2, 3, 4, 5)

# %%
print(hash(myTuple))
# Out:
# -5659871693760987716

# %%
myList = [1, 2, 3, 4, 5]

# %%
print(hash(myList))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4ceb0b52d987> in <module>
# ----> 1 print(hash(myList))
#
# TypeError: unhashable type: 'list'

# %%
# because you can change a list (or mutable)
