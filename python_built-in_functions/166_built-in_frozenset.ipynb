# %%
# python built-in functions: frozenset

# %%
myList = [1, 2, 2, 3, 4, 5]

# %%
frozenList = frozenset(myList)

# %%
print(frozenList) # duplicates removed: 2
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
frozenList[0] = 0 # don't support changes
