# %%
# python built-in functions: all

# %%
votes = [True, False, True, True, True]

# %%
if all(votes):
  print("100 percent pass!")
else:
  print("at least one vote is 'NO'")
# Out:
# at least one vote is 'NO'

# %%
votes = [True, True, True, True, True]

# %%
if all(votes):
  print("100 percent pass!")
else:
  print("at least one vote is 'NO'")
# Out:
# 100 percent pass!
