# %%
# python built-in functions: divmod()

# %%
# divmod
print(divmod(11, 3))
# Out:
# (3, 2)

# %%
# it is equivalen to 
print((11 // 3, 11 % 3))
# Out:
# (3, 2)

# %%
# you will find it useful!
# enjoy coding!
