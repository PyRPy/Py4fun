# %%
# python built-in functions: bytes

# %%
nums = [1, 2, 3, 4, 5]

# %%
print(bytes(nums))
# Out:
# b'\x01\x02\x03\x04\x05'

# %%
myChars = bytes(b'xyz')

# %%
for val in myChars:
  print(val)
# Out:
# 120
# 121
# 122

# %%
print(myChars[2])
# Out:
# 122

# %%
myChars[2] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e1dca55af4f7> in <module>
# ----> 1 myChars[2] = 100
#
# TypeError: 'bytes' object does not support item assignment

# %%
myChars = bytearray(b'xyz')

# %%
myChars[2] = 100 # 100 is mapped to 'd'

# %%
print(myChars)
# Out:
# bytearray(b'xyd')
