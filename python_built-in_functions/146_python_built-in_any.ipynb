# %%
# python built-in functions: any

# %%
votes = [True, False, False, False, False]

# %%
if any(votes):
  print("at least one vote is 'YES'")
else:
  print("all votes are 'NO'!")
# Out:
# at least one vote is 'YES'
