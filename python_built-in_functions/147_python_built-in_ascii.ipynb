# %%
# python built-in functions: ascii

# %%
words = '''first line
second line
third line'''

# %%
print(ascii(words))
# Out:
# 'first line\nsecond line\nthird line'

# %%
print('first line\nsecond line\nthird line')
# Out:
# first line
# second line
# third line
